# %% [markdown]
# <a href="https://colab.research.google.com/github/amshukethireddy/Laptop_price_prediction/blob/main/Laptop_price_predicition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sb
from sklearn import preprocessing
from statsmodels.stats.outliers_influence import variance_inflation_factor
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score

# %%
data = pd.read_csv('laptoppricing.csv')
data
# Out:
#    Manufacturer  IntelCore(i-)  IntelCoreGen  processing speed(GHz)  Ram(gb)  \
# 0          Dell              3             7                   2.29        4
# 1          Dell              3             7                   2.30        4
# 2            HP              3             7                   2.30        8
# 3          ASUS              3             7                   2.30        4
# 4            HP              3             7                   2.40        4
# 5            HP              2             4                   2.30        4
# 6        Lenovo              3             7                   2.30        4
# 7            HP              5             8                   1.60        8
# 8        Lenovo              1             3                   1.80        4
# 9          Dell              3             8                   3.90        4
# 10           HP              3             7                   2.30        8
# ...

# %%
# checking for null values
data.isnull().any()
# Out:
# Manufacturer             False
# IntelCore(i-)            False
# IntelCoreGen             False
# processing speed(GHz)    False
# Ram(gb)                  False
# HDD(gb)                  False
# SSD(gb)                  False
# Graphics(gb)             False
# ScreenSize(inch)         False
# Price                    False
# dtype: bool

# %%
data.columns
# Out:
# Index(['Manufacturer', 'IntelCore(i-)', 'IntelCoreGen',
#        'processing speed(GHz)', 'Ram(gb)', 'HDD(gb)', 'SSD(gb)',
#        'Graphics(gb)', 'ScreenSize(inch)', 'Price'],
#       dtype='object')

# %%
label_encoder = preprocessing.LabelEncoder()
data['Manufacturer'] = data['Manufacturer'].astype('|S')
data['Manufacturer'] = label_encoder.fit_transform(data['Manufacturer'])

# %%
# checking vif
variables = data[['Manufacturer', 'IntelCore(i-)', 'IntelCoreGen',
       'processing speed(GHz)', 'Ram(gb)', 'HDD(gb)', 'SSD(gb)',
       'Graphics(gb)', 'ScreenSize(inch)']]
vif = pd.DataFrame()
vif['VIF'] = [variance_inflation_factor(variables.values, i) for i in range(variables.shape[1])]
vif['Features'] = variables.columns

vif
# Out:
#           VIF               Features
# 0    4.830255           Manufacturer
# 1   40.647852          IntelCore(i-)
# 2   74.128093           IntelCoreGen
# 3   37.604507  processing speed(GHz)
# 4    7.636092                Ram(gb)
# 5   65.612904                HDD(gb)
# 6    4.828394                SSD(gb)
# 7    9.230363           Graphics(gb)
# 8  110.209476       ScreenSize(inch)

# %%
# now, we'll drop columns which have vif>10
data = data.drop(['IntelCore(i-)','IntelCoreGen','processing speed(GHz)','HDD(gb)','ScreenSize(inch)'], axis=1)
data
# Out:
#     Manufacturer  Ram(gb)  SSD(gb)  Graphics(gb)   Price  ï»¿Manufacturer
# 0              1        4        0             0   39057                1
# 1              1        4        0             0   45141                1
# 2              2        8      256             0   35999                2
# 3              0        4        0             0   39990                0
# 4              2        4        0             0   36263                2
# 5              2        4      256             0   26403                2
# 6              3        4        0             0   38290                3
# 7              2        8        0             0   53554                2
# 8              3        4        0             0   29990                3
# 9              1        4        0             0   38090                1
# 10             2        8        0             0   42192                2
# 11             3        4        0             0   34890                3
# ...

# %%
sb.pairplot(data)

# %%
# using Pearson's correlation method
corr = data.corr(method='pearson')
sb.heatmap(corr, annot=True)
# Out:
# <Axes: >

# %%
df = data.values
X,y = df[:,:-1], df[:,-1]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)  # splitting in the ration 80:20

# %%
regr = RandomForestRegressor(random_state=0)
regr.fit(X, y)
# Out:
# RandomForestRegressor(random_state=0)

# %%
y_pred = regr.predict(X_test)

# %%
r2_score(y_test, y_pred)
# Out:
# 0.9998772727272728

# %% [markdown]
# **Accuracy 99.98%**
